# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['font.family'] = 'monospace'
import numpy as np
import pandas as pd
import os
import sys
from adjustText import adjust_text
sys.path.append('..')

# %%
from Util import Globals
from Util import Parser

# %%
def collect_averages(dataset_ids):
    results = []
    for dataset_id in dataset_ids:
        inst_dict = instability_average(dataset_id)
        ar_dict = ar_average(dataset_id)

        technique_list = sorted(ar_dict)
        for i, technique in enumerate(technique_list):
            results.append([dataset_id, Globals.acronyms[technique], i, ar_dict[technique], inst_dict[technique]])

    df = pd.DataFrame(results, columns=['dataset', 'technique', 'label', 'ar', 'inst'])
    return df


def instability_average(dataset_id):
    ct_df = Parser.read_ct_metric(dataset_id)
    rpc_df = Parser.read_rpc_metric(dataset_id)

    means = {}

    technique_list = sorted(rpc_df)
    for i, technique_id in enumerate(technique_list):
        technique_means = []
        for revision in range(int(len(rpc_df[technique_id].columns) / 2)):
            r_col = 'r_' + str(revision)
            b_col = 'b_' + str(revision)
            diff = rpc_df[technique_id][[r_col, b_col]].max(axis=1) - rpc_df[technique_id][b_col]
            ct_mean = diff.dropna().mean()

            r_col = 'r_' + str(revision)
            b_col = 'b_' + str(revision)
            diff = ct_df[technique_id][[r_col, b_col]].max(axis=1) - ct_df[technique_id][b_col]
            rpc_mean = diff.dropna().mean()

            technique_means.append((ct_mean + rpc_mean) / 2)

        means[technique_id] = np.mean(technique_means)

    return means


def ar_average(dataset_id):
    ar_df = Parser.read_aspect_ratios(dataset_id)
    means = {}

    technique_list = sorted(ar_df)
    for i, technique_id in enumerate(technique_list):
        technique_means = []
        for revision in range(int(len(ar_df[technique_id].columns) / 2)):
            # df = ar_df[technique_id]
            w_col = 'w_' + str(revision)
            ar_col = 'ar_' + str(revision)

            u_avg = ar_df[technique_id][ar_col].mean(axis=0)
            w_avg = np.average(ar_df[technique_id][ar_col].dropna(), weights=ar_df[technique_id][w_col].dropna())

            technique_means.append((u_avg + w_avg)/2)

        means[technique_id] = np.mean(technique_means)

    return means

# %%
# dataset_ids = {'DutchNames',
#                 'gh-FlycoTabLayout-m.data',
#                 'gh-pybind11-m.data',
#                 'GitHubAnimate',
#                 'GitHubExo'}
dataset_ids = open('../tvcg-datasets.txt', 'r').readlines()
dataset_ids = [d.replace('\n','') for d in dataset_ids]

# %%
averages = collect_averages(dataset_ids)

# %%
# Remove '.data' from name
averages['dataset'] = averages['dataset'].str.replace(r'.data$', '')

# %%
sorted(averages['dataset'].unique())
# Out:
# ['DutchNames',
#  'GitHubAnimate',
#  'GitHubExo',
#  'GitHubHystrix',
#  'GitHubUws',
#  'MoviesHC9Y1W',
#  'MoviesHC9Y7M',
#  'UNContradeCoffee',
#  'WorldBankExports',
#  'WorldbankHIV',
#  'gh-FlycoTabLayout-m',
#  'gh-pybind11-m',
#  'tmbd-yearly-count-genres-children',
#  'tmbd-yearly-mean-genres-2krand',
#  'tmbd-yearly-std-genres-children',
#  'wb-BX.GSR.CMCP.ZS',
#  'wb-DT.GRE.OFFT',
#  'wb-DT.MAT.OFFT.dataflat',
#  'wb-DT.TDS.MLAT.PG.ZS',
#  'wb-DT.TDS.PNGC.CD.dataflat',
#  'wb-EN.ATM.CO2E.KT.dataflat',
#  'wb-EN.ATM.CO2E.LF.ZS.dataflat',
#  'wb-EN.ATM.METH.EG.KT.CE.dataflat',
#  'wb-EN.ATM.NOXE.ZG',
#  'wb-EN.CO2.BLDG.ZS.dataflat',
#  'wb-EN.CO2.ETOT.ZS',
#  'wb-EN.CO2.MANF.ZS',
#  'wb-EN.POP.DNST',
#  'wb-EN.URB.MCTY.TL.ZS',
#  'wb-FR.INR.RISK',
#  'wb-FR.INR.RISK.dataflat',
#  'wb-GC.XPN.TOTL.GD.ZS',
#  'wb-IQ.SCI.PRDC',
#  'wb-IQ.SCI.PRDC.dataflat',
#  'wb-IS.RRS.PASG.KM',
#  'wb-MS.MIL.XPND.ZS.dataflat',
#  'wb-NY.ADJ.SVNG.GN.ZS.dataflat',
#  'wb-SE.PRE.ENRR.dataflat',
#  'wb-SP.POP.SCIE.RD.P6.dataflat',
#  'wb-TM.VAL.MRCH.R1.ZS.dataflat',
#  'wb-TX.VAL.MMTL.ZS.UN.dataflat']

# %%
dataset_features = pd.read_csv('Selected_datasets.txt', sep='\t')
sorted(dataset_features['Title'].unique())
# Out:
# ['DutchNames',
#  'GitHubAnimate',
#  'GitHubExo',
#  'GitHubHystrix',
#  'GitHubUws',
#  'MoviesHC9Y1W',
#  'MoviesHC9Y7M',
#  'UNContradeCoffee',
#  'WorldBankExports',
#  'WorldbankHIV',
#  'gh-FlycoTabLayout-m',
#  'gh-pybind11-m',
#  'tmbd-yearly-count-genres-children',
#  'tmbd-yearly-mean-genres-2krand',
#  'tmbd-yearly-std-genres-children',
#  'wb-BX.GSR.CMCP.ZS',
#  'wb-DT.GRE.OFFT',
#  'wb-DT.MAT.OFFT.dataflat',
#  'wb-DT.TDS.MLAT.PG.ZS',
#  'wb-DT.TDS.PNGC.CD.dataflat',
#  'wb-EN.ATM.CO2E.KT.dataflat',
#  'wb-EN.ATM.CO2E.LF.ZS.dataflat',
#  'wb-EN.ATM.METH.EG.KT.CE.dataflat',
#  'wb-EN.ATM.NOXE.ZG',
#  'wb-EN.CO2.BLDG.ZS.dataflat',
#  'wb-EN.CO2.ETOT.ZS',
#  'wb-EN.CO2.MANF.ZS',
#  'wb-EN.POP.DNST',
#  'wb-EN.URB.MCTY.TL.ZS',
#  'wb-FR.INR.RISK',
#  'wb-FR.INR.RISK.dataflat',
#  'wb-GC.XPN.TOTL.GD.ZS',
#  'wb-IQ.SCI.PRDC',
#  'wb-IQ.SCI.PRDC.dataflat',
#  'wb-IS.RRS.PASG.KM',
#  'wb-MS.MIL.XPND.ZS.dataflat',
#  'wb-NY.ADJ.SVNG.GN.ZS.dataflat',
#  'wb-SE.PRE.ENRR.dataflat',
#  'wb-SP.POP.SCIE.RD.P6.dataflat',
#  'wb-TM.VAL.MRCH.R1.ZS.dataflat',
#  'wb-TX.VAL.MMTL.ZS.UN.dataflat']

# %%
averages = pd.merge(averages, dataset_features, how='inner', left_on='dataset', right_on='Title')
averages
# Out:
#                            dataset technique  label        ar      inst  \
# 0                       DutchNames       APP      0  0.723925  0.312867
# 1                       DutchNames       HIL      1  0.652042  0.258273
# 2                       DutchNames       MOO      2  0.712259  0.095508
# 3                       DutchNames       LM4      3  0.668185  0.004441
# 4                       DutchNames       LM0      4  0.665904  0.003648
# 5                       DutchNames       PBM      5  0.688400  0.286305
# 6                       DutchNames       PBZ      6  0.638845  0.332664
# 7                       DutchNames       PBS      7  0.659200  0.288382
# 8                       DutchNames       SND      8  0.017636  0.001178
# 9                       DutchNames       SPI      9  0.450762  0.275711
# 10                      DutchNames       SPL     10  0.665363  0.290363
# 11                      DutchNames       SQR     11  0.880363  0.339882
# 12                      DutchNames       STR     12  0.880363  0.343113
# 13             gh-FlycoTabLayout-m       APP      0  0.602155  0.047891
# 14             gh-FlycoTabLayout-m       HIL      1  0.334872  0.034414
# 15             gh-FlycoTabLayout-m       MOO      2  0.499801  0.024736
# 16             gh-FlycoTabLayout-m       LM4      3  0.580474  0.035707
# 17             gh-FlycoTabLayout-m       LM0      4  0.580225  0.006494
# 18             gh-FlycoTabLayout-m       PBM      5  0.503279  0.035429
# 19             gh-FlycoTabLayout-m       PBZ      6  0.433802  0.021187
# 20             gh-FlycoTabLayout-m       PBS      7  0.570192  0.039520
# 21             gh-FlycoTabLayout-m       SND      8  0.244032  0.005904
# 22             gh-FlycoTabLayout-m       SPI      9  0.535265  0.027662
# 23             gh-FlycoTabLayout-m       SPL     10  0.599545  0.043228
# 24             gh-FlycoTabLayout-m       SQR     11  0.562798  0.027962
# 25             gh-FlycoTabLayout-m       STR     12  0.562798  0.027824
# 26                   gh-pybind11-m       APP      0  0.693590  0.108540
# 27                   gh-pybind11-m       HIL      1  0.477991  0.110573
# 28                   gh-pybind11-m       MOO      2  0.460635  0.073472
# 29                   gh-pybind11-m       LM4      3  0.624086  0.017415
# ..                             ...       ...    ...       ...       ...
# 503  wb-TX.VAL.MMTL.ZS.UN.dataflat       SPI      9  0.344151  0.324559
# 504  wb-TX.VAL.MMTL.ZS.UN.dataflat       SPL     10  0.679598  0.198623
# 505  wb-TX.VAL.MMTL.ZS.UN.dataflat       SQR     11  0.766684  0.234210
# 506  wb-TX.VAL.MMTL.ZS.UN.dataflat       STR     12  0.766684  0.235953
# 507               WorldBankExports       APP      0  0.668346  0.183696
# 508               WorldBankExports       HIL      1  0.611567  0.181526
# 509               WorldBankExports       MOO      2  0.540085  0.083977
# 510               WorldBankExports       LM4      3  0.668813  0.007217
# 511               WorldBankExports       LM0      4  0.652989  0.007898
# 512               WorldBankExports       PBM      5  0.664257  0.172062
# 513               WorldBankExports       PBZ      6  0.600433  0.183740
# 514               WorldBankExports       PBS      7  0.669944  0.180394
# 515               WorldBankExports       SND      8  0.243339  0.004939
# 516               WorldBankExports       SPI      9  0.482704  0.150091
# 517               WorldBankExports       SPL     10  0.663756  0.177412
# 518               WorldBankExports       SQR     11  0.794536  0.203311
# 519               WorldBankExports       STR     12  0.799853  0.195195
# 520                   WorldbankHIV       APP      0  0.659574  0.178194
# 521                   WorldbankHIV       HIL      1  0.657581  0.153348
# 522                   WorldbankHIV       MOO      2  0.506274  0.082364
# 523                   WorldbankHIV       LM4      3  0.482980  0.006246
# 524                   WorldbankHIV       LM0      4  0.502796  0.006552
# 525                   WorldbankHIV       PBM      5  0.584514  0.101391
# 526                   WorldbankHIV       PBZ      6  0.590871  0.165036
# 527                   WorldbankHIV       PBS      7  0.681074  0.139974
# 528                   WorldbankHIV       SND      8  0.041507  0.000715
# 529                   WorldbankHIV       SPI      9  0.277192  0.073289
# 530                   WorldbankHIV       SPL     10  0.674557  0.179066
# 531                   WorldbankHIV       SQR     11  0.664191  0.139592
# 532                   WorldbankHIV       STR     12  0.664191  0.141757
#
#                              Title  maxNodes  timesteps  depthCategory  \
# 0                       DutchNames        61         22   Single level
# 1                       DutchNames        61         22   Single level
# 2                       DutchNames        61         22   Single level
# 3                       DutchNames        61         22   Single level
# 4                       DutchNames        61         22   Single level
# 5                       DutchNames        61         22   Single level
# 6                       DutchNames        61         22   Single level
# 7                       DutchNames        61         22   Single level
# 8                       DutchNames        61         22   Single level
# 9                       DutchNames        61         22   Single level
# 10                      DutchNames        61         22   Single level
# 11                      DutchNames        61         22   Single level
# 12                      DutchNames        61         22   Single level
# 13             gh-FlycoTabLayout-m        35          9      4+ levels
# 14             gh-FlycoTabLayout-m        35          9      4+ levels
# 15             gh-FlycoTabLayout-m        35          9      4+ levels
# 16             gh-FlycoTabLayout-m        35          9      4+ levels
# 17             gh-FlycoTabLayout-m        35          9      4+ levels
# 18             gh-FlycoTabLayout-m        35          9      4+ levels
# 19             gh-FlycoTabLayout-m        35          9      4+ levels
# 20             gh-FlycoTabLayout-m        35          9      4+ levels
# 21             gh-FlycoTabLayout-m        35          9      4+ levels
# 22             gh-FlycoTabLayout-m        35          9      4+ levels
# 23             gh-FlycoTabLayout-m        35          9      4+ levels
# 24             gh-FlycoTabLayout-m        35          9      4+ levels
# 25             gh-FlycoTabLayout-m        35          9      4+ levels
# 26                   gh-pybind11-m       133         36      4+ levels
# 27                   gh-pybind11-m       133         36      4+ levels
# 28                   gh-pybind11-m       133         36      4+ levels
# 29                   gh-pybind11-m       133         36      4+ levels
# ..                             ...       ...        ...            ...
# 503  wb-TX.VAL.MMTL.ZS.UN.dataflat       163         56   Single level
# 504  wb-TX.VAL.MMTL.ZS.UN.dataflat       163         56   Single level
# 505  wb-TX.VAL.MMTL.ZS.UN.dataflat       163         56   Single level
# 506  wb-TX.VAL.MMTL.ZS.UN.dataflat       163         56   Single level
# 507               WorldBankExports       186         56  2 or 3 levels
# 508               WorldBankExports       186         56  2 or 3 levels
# 509               WorldBankExports       186         56  2 or 3 levels
# 510               WorldBankExports       186         56  2 or 3 levels
# 511               WorldBankExports       186         56  2 or 3 levels
# 512               WorldBankExports       186         56  2 or 3 levels
# 513               WorldBankExports       186         56  2 or 3 levels
# 514               WorldBankExports       186         56  2 or 3 levels
# 515               WorldBankExports       186         56  2 or 3 levels
# 516               WorldBankExports       186         56  2 or 3 levels
# 517               WorldBankExports       186         56  2 or 3 levels
# 518               WorldBankExports       186         56  2 or 3 levels
# 519               WorldBankExports       186         56  2 or 3 levels
# 520                   WorldbankHIV       108         25   Single level
# 521                   WorldbankHIV       108         25   Single level
# 522                   WorldbankHIV       108         25   Single level
# 523                   WorldbankHIV       108         25   Single level
# 524                   WorldbankHIV       108         25   Single level
# 525                   WorldbankHIV       108         25   Single level
# 526                   WorldbankHIV       108         25   Single level
# 527                   WorldbankHIV       108         25   Single level
# 528                   WorldbankHIV       108         25   Single level
# 529                   WorldbankHIV       108         25   Single level
# 530                   WorldbankHIV       108         25   Single level
# 531                   WorldbankHIV       108         25   Single level
# 532                   WorldbankHIV       108         25   Single level
#
#     sizeVarianceCategory   sizeChangeCategory   dataChangeCategory
# 0           Low variance  Regular size change      Low data change
# 1           Low variance  Regular size change      Low data change
# 2           Low variance  Regular size change      Low data change
# 3           Low variance  Regular size change      Low data change
# 4           Low variance  Regular size change      Low data change
# 5           Low variance  Regular size change      Low data change
# 6           Low variance  Regular size change      Low data change
# 7           Low variance  Regular size change      Low data change
# 8           Low variance  Regular size change      Low data change
# 9           Low variance  Regular size change      Low data change
# 10          Low variance  Regular size change      Low data change
# 11          Low variance  Regular size change      Low data change
# 12          Low variance  Regular size change      Low data change
# 13         High variance    Spiky size change      Low data change
# 14         High variance    Spiky size change      Low data change
# 15         High variance    Spiky size change      Low data change
# 16         High variance    Spiky size change      Low data change
# 17         High variance    Spiky size change      Low data change
# 18         High variance    Spiky size change      Low data change
# 19         High variance    Spiky size change      Low data change
# 20         High variance    Spiky size change      Low data change
# 21         High variance    Spiky size change      Low data change
# 22         High variance    Spiky size change      Low data change
# 23         High variance    Spiky size change      Low data change
# 24         High variance    Spiky size change      Low data change
# 25         High variance    Spiky size change      Low data change
# 26         High variance  Regular size change    Spiky data change
# 27         High variance  Regular size change    Spiky data change
# 28         High variance  Regular size change    Spiky data change
# 29         High variance  Regular size change    Spiky data change
# ..                   ...                  ...                  ...
# 503        High variance  Regular size change  Regular data change
# 504        High variance  Regular size change  Regular data change
# 505        High variance  Regular size change  Regular data change
# 506        High variance  Regular size change  Regular data change
# 507         Low variance  Regular size change      Low data change
# 508         Low variance  Regular size change      Low data change
# 509         Low variance  Regular size change      Low data change
# 510         Low variance  Regular size change      Low data change
# 511         Low variance  Regular size change      Low data change
# 512         Low variance  Regular size change      Low data change
# 513         Low variance  Regular size change      Low data change
# 514         Low variance  Regular size change      Low data change
# 515         Low variance  Regular size change      Low data change
# 516         Low variance  Regular size change      Low data change
# 517         Low variance  Regular size change      Low data change
# 518         Low variance  Regular size change      Low data change
# 519         Low variance  Regular size change      Low data change
# 520        High variance  Regular size change      Low data change
# 521        High variance  Regular size change      Low data change
# 522        High variance  Regular size change      Low data change
# 523        High variance  Regular size change      Low data change
# 524        High variance  Regular size change      Low data change
# 525        High variance  Regular size change      Low data change
# 526        High variance  Regular size change      Low data change
# 527        High variance  Regular size change      Low data change
# 528        High variance  Regular size change      Low data change
# 529        High variance  Regular size change      Low data change
# 530        High variance  Regular size change      Low data change
# 531        High variance  Regular size change      Low data change
# 532        High variance  Regular size change      Low data change
#
# [533 rows x 12 columns]

# %%
for technique in sorted(Globals.acronyms):
    df = averages[(averages['technique'] == Globals.acronyms[technique])]#.dropna(axis=0)
    print(len(df))
# Out:
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41

# %%
attrs = ['Single level', '2 or 3 levels', '4+ levels']

fig, _ = plt.subplots(1, len(attrs), sharex=True, sharey=True, figsize=(len(attrs) * 7, 7))
fig.suptitle('Depth category', fontsize=20)

for i, attr in enumerate(attrs):
    ax = fig.axes[i]
    ax.set_title(attr, fontsize=18)
    ax.set_xlabel('Stability')
    ax.set_ylabel('Visual quality')

    texts = []
    for i in range(len(attrs)):
        texts.append([])

    for technique in sorted(Globals.acronyms):
        df = averages[(averages['technique'] == Globals.acronyms[technique])]#.dropna(axis=0)
        colors = [Globals.tech_to_color[technique] for i in range(len(df['label'].values))]
        labels = Globals.acronyms[technique]
        
        x_mean = df['inst'].mean()
        y_mean = df['ar'].mean()

        for j, point in df.iterrows():
            x_line = [x_mean, point['inst']]
            y_line = [y_mean, point['ar']]

            if point['depthCategory'] == attr:
                ax.plot(x_line, y_line, c=colors[0], linewidth=2, zorder=1, alpha=.4)
            else:
                ax.plot(x_line, y_line, c='#000000', zorder=1, alpha=.05)


        ax.scatter(x_mean, y_mean, s=80, c=colors, label=labels, linewidth=1, zorder=10)

        t = ax.text(x_mean, y_mean, Globals.acronyms[technique], ha='center', va='center', zorder=11,
                     fontsize=14, fontweight='bold')
        texts[i].append(t)
    adjust_text(texts[i], ax=ax, force_points=1, force_text=1, expand_points=(1,1), expand_text=(.3,.5))

    plt.xlim(xmin=0)
    plt.ylim(ymin=0, ymax=1)

plt.tight_layout()
plt.subplots_adjust(top=0.88)
plt.show()
os.makedirs('./modified_scatter', exist_ok=True)
fig.savefig('./modified_scatter/depthCategory.png', dpi=400)

# %%
attrs = ['Low variance', 'High variance']

fig, _ = plt.subplots(1, len(attrs), sharex=True, sharey=True, figsize=(len(attrs) * 7, 7))
fig.suptitle('Size Variance Category', fontsize=20)

for i, attr in enumerate(attrs):
    ax = fig.axes[i]
    ax.set_title(attr, fontsize=18)
    ax.set_xlabel('Stability')
    ax.set_ylabel('Visual quality')

    texts = []
    for i in range(len(attrs)):
        texts.append([])

    for technique in sorted(Globals.acronyms):
        df = averages[(averages['technique'] == Globals.acronyms[technique])]#.dropna(axis=0)
        colors = [Globals.tech_to_color[technique] for i in range(len(df['label'].values))]
        labels = Globals.acronyms[technique]

        x_mean = df['inst'].mean()
        y_mean = df['ar'].mean()

        for j, point in df.iterrows():
            x_line = [x_mean, point['inst']]
            y_line = [y_mean, point['ar']]

            if point['sizeVarianceCategory'] == attr:
                ax.plot(x_line, y_line, c=colors[0], linewidth=2, zorder=1, alpha=.4)
            else:
                ax.plot(x_line, y_line, c='#000000', zorder=1, alpha=.05)


        ax.scatter(x_mean, y_mean, s=80, c=colors, label=labels, linewidth=1, zorder=10)

        t = ax.text(x_mean, y_mean, Globals.acronyms[technique], ha='center', va='center', zorder=11,
                     fontsize=14, fontweight='bold')
        texts[i].append(t)
    adjust_text(texts[i], ax=ax, force_points=0.2, force_text=0.2, expand_points=(1,1), expand_text=(.3,.5))

    plt.xlim(xmin=0)
    plt.ylim(ymin=0, ymax=1)

plt.tight_layout()
plt.subplots_adjust(top=0.88)
plt.show()
os.makedirs('./modified_scatter', exist_ok=True)
fig.savefig('./modified_scatter/varianceCategory.png', dpi=400)

# %%
attrs = ['Low data change', 'Regular data change', 'Spiky data change']

fig, _ = plt.subplots(1, len(attrs), sharex=True, sharey=True, figsize=(len(attrs) * 7, 7))
fig.suptitle('Data Change Category', fontsize=20)

for i, attr in enumerate(attrs):
    ax = fig.axes[i]
    ax.set_title(attr, fontsize=18)
    ax.set_xlabel('Stability')
    ax.set_ylabel('Visual quality')

    texts = []
    for i in range(len(attrs)):
        texts.append([])

    for technique in sorted(Globals.acronyms):
        df = averages[(averages['technique'] == Globals.acronyms[technique])]#.dropna(axis=0)
        colors = [Globals.tech_to_color[technique] for i in range(len(df['label'].values))]
        labels = Globals.acronyms[technique]
      
        x_mean = df['inst'].mean()
        y_mean = df['ar'].mean()

        for j, point in df.iterrows():
            x_line = [x_mean, point['inst']]
            y_line = [y_mean, point['ar']]

            if point['dataChangeCategory'] == attr:
                ax.plot(x_line, y_line, c=colors[0], linewidth=2, zorder=1, alpha=.4)
            else:
                ax.plot(x_line, y_line, c='#000000', zorder=1, alpha=.05)



        ax.scatter(x_mean, y_mean, s=80, c=colors, label=labels, linewidth=1, zorder=10)

        t = ax.text(x_mean, y_mean, Globals.acronyms[technique], ha='center', va='center', zorder=11,
                     fontsize=14, fontweight='bold')
        texts[i].append(t)
    adjust_text(texts[i], ax=ax, force_points=0.2, force_text=0.2, expand_points=(1,1), expand_text=(.3,.5))

    plt.xlim(xmin=0)
    plt.ylim(ymin=0, ymax=1)

plt.tight_layout()
plt.subplots_adjust(top=0.88)
plt.show()
os.makedirs('./modified_scatter', exist_ok=True)
fig.savefig('./modified_scatter/dataChangeCategory.png', dpi=400)

# %%
attrs = ['Low size change', 'Regular size change', 'Spiky size change']

fig, _ = plt.subplots(1, len(attrs), sharex=True, sharey=True, figsize=(len(attrs) * 7, 7))
fig.suptitle('Size Change Category', fontsize=20)

for i, attr in enumerate(attrs):
    ax = fig.axes[i]
    ax.set_title(attr, fontsize=18)
    ax.set_xlabel('Stability')
    ax.set_ylabel('Visual quality')

    texts = []
    for i in range(len(attrs)):
        texts.append([])

    for technique in sorted(Globals.acronyms):
        df = averages[(averages['technique'] == Globals.acronyms[technique])]#.dropna(axis=0)
        colors = [Globals.tech_to_color[technique] for i in range(len(df['label'].values))]
        labels = Globals.acronyms[technique]

        x_mean = df['inst'].mean()
        y_mean = df['ar'].mean()

        for j, point in df.iterrows():
            x_line = [x_mean, point['inst']]
            y_line = [y_mean, point['ar']]

            if point['sizeChangeCategory'] == attr:
                ax.plot(x_line, y_line, c=colors[0], linewidth=2, zorder=1, alpha=.4)
            else:
                ax.plot(x_line, y_line, c='#000000', zorder=1, alpha=.05)


        ax.scatter(x_mean, y_mean, s=80, c=colors, label=labels, linewidth=1, zorder=10)

        t = ax.text(x_mean, y_mean, Globals.acronyms[technique], ha='center', va='center', zorder=11,
                     fontsize=14, fontweight='bold')
        texts[i].append(t)
    adjust_text(texts[i], ax=ax, force_points=0.2, force_text=0.2, expand_points=(1,1), expand_text=(.3,.5))

    plt.xlim(xmin=0)
    plt.ylim(ymin=0, ymax=1)

plt.tight_layout()
plt.subplots_adjust(top=0.88)
plt.show()
os.makedirs('./modified_scatter', exist_ok=True)
fig.savefig('./modified_scatter/sizeChangeCategory.png', dpi=400)
